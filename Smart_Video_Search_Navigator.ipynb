# %%
pip install moviepy SpeechRecognition transformers torch
# Out:
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.10.4-py2.py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.0+cu121)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.66.5)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from moviepy) (1.26.4)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.34.2)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.5.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy) (9.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy) (71.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Downloading SpeechRecognition-3.10.4-py2.py3-none-any.whl (32.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 29.2 MB/s eta 0:00:00
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.10.4

# %%
pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
import torch
import os
import numpy as np
import h5py
import speech_recognition as sr  # For speech-to-text
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity
import moviepy.editor as mp
import torch
import moviepy.editor as mp
import speech_recognition as sr
from pydub import AudioSegment
import os

# %%
def convert_audio_to_text(video_file):
    print('... extracting audio and converting to text')

    # Extract audio from the video
    video = mp.VideoFileClip(video_file)
    audio_file = video_file.replace(".mkv", ".wav")
    video.audio.write_audiofile(audio_file)

    # Load audio file for processing
    audio = AudioSegment.from_wav(audio_file)
    recognizer = sr.Recognizer()

    timestamps = []
    text_data = []


    segment_duration_ms = 10000  # 10 seconds
    total_duration_ms = len(audio)  # Total duration of the audio in milliseconds

    # Process audio in chunks
    for start_time_ms in range(0, total_duration_ms, segment_duration_ms):
        end_time_ms = min(start_time_ms + segment_duration_ms, total_duration_ms)
        segment = audio[start_time_ms:end_time_ms]
        segment_file = "segment.wav"
        segment.export(segment_file, format="wav")

        with sr.AudioFile(segment_file) as source:
            try:
                print(f"... processing segment {start_time_ms / 1000} to {end_time_ms / 1000} seconds")
                audio_chunk = recognizer.record(source)
                transcript = recognizer.recognize_google(audio_chunk)

                # Record timestamp and text
                timestamps.append(start_time_ms / 1000)
                text_data.append(transcript)

            except sr.UnknownValueError:
                print(f"... segment {start_time_ms / 1000} to {end_time_ms / 1000} could not be understood")
            except sr.RequestError as e:
                print(f"Could not request results from Google Speech Recognition service; {e}")

        # Clean up temporary segment file
        os.remove(segment_file)

    # Print results
    print(f"Timestamps: {timestamps}")
    print(f"Text Data: {text_data}")

    return timestamps, text_data


def get_text_embeddings(text_data):
    print('... converting text to embeddings')
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = BertModel.from_pretrained('bert-base-uncased')

    embeddings = []

    for sentence in text_data:
        inputs = tokenizer(sentence, return_tensors="pt")
        with torch.no_grad():
            outputs = model(**inputs)
        sentence_embedding = outputs.pooler_output.squeeze().numpy()
        embeddings.append(sentence_embedding)

    return np.array(embeddings)  # This should be 2D: (num_texts, embedding_dim)

def convert_text_to_embedding(text):
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    model = BertModel.from_pretrained('bert-base-uncased')

    inputs = tokenizer(text, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)

    return outputs.pooler_output.squeeze().numpy().reshape(1, -1)  # Ensure it's 2D

# Step 3: Search Keywords and Jump to Video
def search_video(keyword, text_embeddings, timestamps):
    from sklearn.metrics.pairwise import cosine_similarity

    if len(text_embeddings) == 0:
        raise ValueError("The embeddings array is empty. Ensure text was correctly converted to embeddings.")

    keyword_embedding = convert_text_to_embedding(keyword)

    if text_embeddings.ndim == 1:
        text_embeddings = text_embeddings.reshape(1, -1)
    elif text_embeddings.ndim > 2:
        raise ValueError("text_embeddings has more than 2 dimensions")

    similarities = cosine_similarity(keyword_embedding, text_embeddings)

    best_idx = np.argmax(similarities)

    return timestamps[best_idx]

def jump_to_timestamp(video_file, timestamp):
    print(f"... jumping to timestamp: {timestamp} seconds")
    video = mp.VideoFileClip(video_file)
    end_time = video.duration
    video.subclip(timestamp, end_time).preview()

# Main Process
if __name__ == '__main__':
    video_file = 'video_file'
    timestamps, text_data = convert_audio_to_text(video_file)


    text_embeddings = get_text_embeddings(text_data)


    keyword = "keyword"
    timestamp = search_video(keyword, text_embeddings, timestamps)

    print(f"Timestamp to jump to for keyword '{keyword}': {timestamp} seconds")

    jump_to_timestamp(video_file, timestamp)
# Out:
# ... extracting audio and converting to text
# MoviePy - Writing audio in /content/drive/MyDrive/Rick and Morty S03E03 {English} 720p WEB-DL ESub [BollyFlix].wav
# MoviePy - Done.
# ... processing segment 0.0 to 10.0 seconds
# ... processing segment 10.0 to 20.0 seconds
# ... processing segment 20.0 to 30.0 seconds
# ... processing segment 30.0 to 40.0 seconds
# ... processing segment 40.0 to 50.0 seconds
# ... processing segment 50.0 to 60.0 seconds
# ... processing segment 60.0 to 70.0 seconds
# ... segment 60.0 to 70.0 could not be understood
# ... processing segment 70.0 to 80.0 seconds
# ... segment 70.0 to 80.0 could not be understood
# ... processing segment 80.0 to 90.0 seconds
# ... segment 80.0 to 90.0 could not be understood
# ... processing segment 90.0 to 100.0 seconds
# ... processing segment 100.0 to 110.0 seconds
# ... processing segment 110.0 to 120.0 seconds
# ... processing segment 120.0 to 130.0 seconds
# ... processing segment 130.0 to 140.0 seconds
# ... processing segment 140.0 to 150.0 seconds
# ... processing segment 150.0 to 160.0 seconds
# ... processing segment 160.0 to 170.0 seconds
# ... processing segment 170.0 to 180.0 seconds
# ... processing segment 180.0 to 190.0 seconds
# ... processing segment 190.0 to 200.0 seconds
# ... processing segment 200.0 to 210.0 seconds
# ... processing segment 210.0 to 220.0 seconds
# ... processing segment 220.0 to 230.0 seconds
# ... processing segment 230.0 to 240.0 seconds
# ... processing segment 240.0 to 250.0 seconds
# ... segment 240.0 to 250.0 could not be understood
# ... processing segment 250.0 to 260.0 seconds
# ... processing segment 260.0 to 270.0 seconds
# ... segment 260.0 to 270.0 could not be understood
# ... processing segment 270.0 to 280.0 seconds
# ... processing segment 280.0 to 290.0 seconds
# ... segment 280.0 to 290.0 could not be understood
# ... processing segment 290.0 to 300.0 seconds
# ... processing segment 300.0 to 310.0 seconds
# ... segment 300.0 to 310.0 could not be understood
# ... processing segment 310.0 to 320.0 seconds
# ... segment 310.0 to 320.0 could not be understood
# ... processing segment 320.0 to 330.0 seconds
# ... processing segment 330.0 to 340.0 seconds
# ... segment 330.0 to 340.0 could not be understood
# ... processing segment 340.0 to 350.0 seconds
# ... segment 340.0 to 350.0 could not be understood
# ... processing segment 350.0 to 360.0 seconds
# ... segment 350.0 to 360.0 could not be understood
# ... processing segment 360.0 to 370.0 seconds
# ... processing segment 370.0 to 380.0 seconds
# ... processing segment 380.0 to 390.0 seconds
# ... processing segment 390.0 to 400.0 seconds
# ... processing segment 400.0 to 410.0 seconds
# ... segment 400.0 to 410.0 could not be understood
# ... processing segment 410.0 to 420.0 seconds
# ... processing segment 420.0 to 430.0 seconds
# ... processing segment 430.0 to 440.0 seconds
# ... processing segment 440.0 to 450.0 seconds
# ... processing segment 450.0 to 460.0 seconds
# ... processing segment 460.0 to 470.0 seconds
# ... segment 460.0 to 470.0 could not be understood
# ... processing segment 470.0 to 480.0 seconds
# ... processing segment 480.0 to 490.0 seconds
# ... processing segment 490.0 to 500.0 seconds
# ... segment 490.0 to 500.0 could not be understood
# ... processing segment 500.0 to 510.0 seconds
# ... segment 500.0 to 510.0 could not be understood
# ... processing segment 510.0 to 520.0 seconds
# ... segment 510.0 to 520.0 could not be understood
# ... processing segment 520.0 to 530.0 seconds
# ... segment 520.0 to 530.0 could not be understood
# ... processing segment 530.0 to 540.0 seconds
# ... segment 530.0 to 540.0 could not be understood
# ... processing segment 540.0 to 550.0 seconds
# ... processing segment 550.0 to 560.0 seconds
# ... processing segment 560.0 to 570.0 seconds
# ... processing segment 570.0 to 580.0 seconds
# ... processing segment 580.0 to 590.0 seconds
# ... processing segment 590.0 to 600.0 seconds
# ... processing segment 600.0 to 610.0 seconds
# ... segment 600.0 to 610.0 could not be understood
# ... processing segment 610.0 to 620.0 seconds
# ... segment 610.0 to 620.0 could not be understood
# ... processing segment 620.0 to 630.0 seconds
# ... processing segment 630.0 to 640.0 seconds
# ... processing segment 640.0 to 650.0 seconds
# ... segment 640.0 to 650.0 could not be understood
# ... processing segment 650.0 to 660.0 seconds
# ... segment 650.0 to 660.0 could not be understood
# ... processing segment 660.0 to 670.0 seconds
# ... segment 660.0 to 670.0 could not be understood
# ... processing segment 670.0 to 680.0 seconds
# ... processing segment 680.0 to 690.0 seconds
# ... processing segment 690.0 to 700.0 seconds
# ... processing segment 700.0 to 710.0 seconds
# ... segment 700.0 to 710.0 could not be understood
# ... processing segment 710.0 to 720.0 seconds
# ... processing segment 720.0 to 730.0 seconds
# ... processing segment 730.0 to 740.0 seconds
# ... processing segment 740.0 to 750.0 seconds
# ... segment 740.0 to 750.0 could not be understood
# ... processing segment 750.0 to 760.0 seconds
# ... processing segment 760.0 to 770.0 seconds
# ... processing segment 770.0 to 780.0 seconds
# ... segment 770.0 to 780.0 could not be understood
# ... processing segment 780.0 to 790.0 seconds
# ... segment 780.0 to 790.0 could not be understood
# ... processing segment 790.0 to 800.0 seconds
# ... processing segment 800.0 to 810.0 seconds
# ... processing segment 810.0 to 820.0 seconds
# ... processing segment 820.0 to 830.0 seconds
# ... processing segment 830.0 to 840.0 seconds
# ... segment 830.0 to 840.0 could not be understood
# ... processing segment 840.0 to 850.0 seconds
# ... processing segment 850.0 to 860.0 seconds
# ... segment 850.0 to 860.0 could not be understood
# ... processing segment 860.0 to 870.0 seconds
# ... segment 860.0 to 870.0 could not be understood
# ... processing segment 870.0 to 880.0 seconds
# ... processing segment 880.0 to 890.0 seconds
# ... segment 880.0 to 890.0 could not be understood
# ... processing segment 890.0 to 900.0 seconds
# ... segment 890.0 to 900.0 could not be understood
# ... processing segment 900.0 to 910.0 seconds
# ... processing segment 910.0 to 920.0 seconds
# ... processing segment 920.0 to 930.0 seconds
# ... segment 920.0 to 930.0 could not be understood
# ... processing segment 930.0 to 940.0 seconds
# ... processing segment 940.0 to 950.0 seconds
# ... processing segment 950.0 to 960.0 seconds
# ... processing segment 960.0 to 970.0 seconds
# ... processing segment 970.0 to 980.0 seconds
# ... processing segment 980.0 to 990.0 seconds
# ... segment 980.0 to 990.0 could not be understood
# ... processing segment 990.0 to 1000.0 seconds
# ... segment 990.0 to 1000.0 could not be understood
# ... processing segment 1000.0 to 1010.0 seconds
# ... processing segment 1010.0 to 1020.0 seconds
# ... processing segment 1020.0 to 1030.0 seconds
# ... segment 1020.0 to 1030.0 could not be understood
# ... processing segment 1030.0 to 1040.0 seconds
# ... segment 1030.0 to 1040.0 could not be understood
# ... processing segment 1040.0 to 1050.0 seconds
# ... segment 1040.0 to 1050.0 could not be understood
# ... processing segment 1050.0 to 1060.0 seconds
# ... processing segment 1060.0 to 1070.0 seconds
# ... processing segment 1070.0 to 1080.0 seconds
# ... processing segment 1080.0 to 1090.0 seconds
# ... processing segment 1090.0 to 1100.0 seconds
# ... processing segment 1100.0 to 1110.0 seconds
# ... segment 1100.0 to 1110.0 could not be understood
# ... processing segment 1110.0 to 1120.0 seconds
# ... processing segment 1120.0 to 1130.0 seconds
# ... processing segment 1130.0 to 1140.0 seconds
# ... processing segment 1140.0 to 1150.0 seconds
# ... processing segment 1150.0 to 1160.0 seconds
# ... processing segment 1160.0 to 1170.0 seconds
# ... processing segment 1170.0 to 1180.0 seconds
# ... processing segment 1180.0 to 1190.0 seconds
# ... processing segment 1190.0 to 1200.0 seconds
# ... processing segment 1200.0 to 1210.0 seconds
# ... processing segment 1210.0 to 1220.0 seconds
# ... processing segment 1220.0 to 1230.0 seconds
# ... processing segment 1230.0 to 1240.0 seconds
# ... processing segment 1240.0 to 1250.0 seconds
# ... processing segment 1250.0 to 1260.0 seconds
# ... processing segment 1260.0 to 1270.0 seconds
# ... processing segment 1270.0 to 1280.0 seconds
# ... segment 1270.0 to 1280.0 could not be understood
# ... processing segment 1280.0 to 1290.0 seconds
# ... processing segment 1290.0 to 1300.0 seconds
# ... segment 1290.0 to 1300.0 could not be understood
# ... processing segment 1300.0 to 1310.0 seconds
# ... segment 1300.0 to 1310.0 could not be understood
# ... processing segment 1310.0 to 1320.0 seconds
# ... processing segment 1320.0 to 1330.0 seconds
# ... processing segment 1330.0 to 1340.0 seconds
# ... segment 1330.0 to 1340.0 could not be understood
# ... processing segment 1340.0 to 1350.0 seconds
# ... segment 1340.0 to 1350.0 could not be understood
# ... processing segment 1350.0 to 1360.0 seconds
# ... segment 1350.0 to 1360.0 could not be understood
# ... processing segment 1360.0 to 1370.0 seconds
# ... processing segment 1370.0 to 1380.0 seconds
# ... processing segment 1380.0 to 1390.0 seconds
# ... processing segment 1390.0 to 1400.0 seconds
# ... processing segment 1400.0 to 1405.24 seconds
# ... segment 1400.0 to 1405.24 could not be understood
# Timestamps: [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 90.0, 100.0, 110.0, 120.0, 130.0, 140.0, 150.0, 160.0, 170.0, 180.0, 190.0, 200.0, 210.0, 220.0, 230.0, 250.0, 270.0, 290.0, 320.0, 360.0, 370.0, 380.0, 390.0, 410.0, 420.0, 430.0, 440.0, 450.0, 470.0, 480.0, 540.0, 550.0, 560.0, 570.0, 580.0, 590.0, 620.0, 630.0, 670.0, 680.0, 690.0, 710.0, 720.0, 730.0, 750.0, 760.0, 790.0, 800.0, 810.0, 820.0, 840.0, 870.0, 900.0, 910.0, 930.0, 940.0, 950.0, 960.0, 970.0, 1000.0, 1010.0, 1050.0, 1060.0, 1070.0, 1080.0, 1090.0, 1110.0, 1120.0, 1130.0, 1140.0, 1150.0, 1160.0, 1170.0, 1180.0, 1190.0, 1200.0, 1210.0, 1220.0, 1230.0, 1240.0, 1250.0, 1260.0, 1280.0, 1310.0, 1320.0, 1360.0, 1370.0, 1380.0, 1390.0]
# Text Data: ['Morty Morty Rick hey Morty Rick are you far', 'are you inside something is this a camera is everything a camera the garage Morty come to the garage Morty Rick', "where are you on my workbench Morty are you invisible and you're going to like fart on me flip the pickle over what I'm going to touch it and you're going to tell me it's an alien dick or something come on flip the pick", "40 you're not going to regret it to pay off is huge I turn myself into a pickle Morty Boom Big reveal I'm a pickle what do you think about that I turned myself into", 'what are you just staring at me for bro I turned myself into a pickle Morty hand and what more do you want text on to this I turned myself into a pickle and 9/11 was an inside', "who cares Morty Global acts of terrorism happen everyday here's something that's never happened before I'm a pickle I'm pickle Rick", 'are you going to I mean you know is this the first part of some kind of magic trick', "do magic Morty I do science one takes brains the other takes dark eyeliner well can you move can you fly wouldn't be much of a pickle if I could all right we'll do pickles live", "I'm just trying to figure out why you would do this why anyone would do this the reason anyone would do this", "if they could which they can't would be because they could which they can't be late where is your grandpa right here sweetie I'm a pickle", 'we have an appointment downtown that was set a week ago and agreed upon by everyone incl', "it totally slipped my mind geez oh man I'm a pickle I mean I don't know if I can you do this on purpose to get out of", "turn me so we're making eye contact Marty I assure you I", "never find a way to get out of family therapy I hope my lack of fingers doesn't prevent the perception of my air quotes can't you just turn yourself back into a human great question summer", "the unfortunate answer is I did this to challenge myself and it could take hours or even days before I'm able to figure out how to return to human form but I mean you know your mom could put me in a purse or a", "you know if she really needs me to go nobody needs anything okay it's fine I mean you should just stay here and figure out how to stop being a pickle okay hey Rick why is there a syringe a mysterious flu", "who's hanging directly over you also why is the string attached to it running through a pair of scissors attached to a timer and why is the timer set to 10 minutes from now exactly when we would have left for therapy", 'will Morty if you must know the syringe is completely unrelated to this discussion and therefore does not warrant further explanation enough kids', "time to go we don't want to be late what are you doing what are you doing there sweetie I'm related to your situation how's that going to help can't", "we'll see you later hey be careful with that it's for something else it's really important so don't break it okay I may have fucked up here", 'Papa Papa Papa Papa Papa Papa Papa Papa Papa Papa Papa Papa', "whoa whoa whoa whoa I know what it looks like to you is it but I'm not a snake I've seen the YouTube videos I know cats are scared of cucumbers and pickles because they think they're snakes I'm not", 'this is the Mega genius equivalent of dying on the toilet so hot', 'oh God moisture moisture toilet paper', "come on that's it", "how is this even family therapy if Dad's not invited and Grandpa won't come yeah and what's Courageous about eating a hot dog it's nobody's choice to be here", "the family was told to get counseling by your principal even though it's not the family that was huffing Pottery glaze in the art room and desk wedding in history class", 'temporarily by order of the school me to how long have you all been eating poop', 'we have never eaten poop say where did my family get off to Smith family', "have an experiment he's a scientist like legit like on an Intergalactic sci-fi level his work is very turn himself into a pickle", 'does Grandpa turn himself into a  ...
# ... converting text to embeddings
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Timestamp to jump to for keyword 'jaguar': 1010.0 seconds
# ... jumping to timestamp: 1010.0 seconds
